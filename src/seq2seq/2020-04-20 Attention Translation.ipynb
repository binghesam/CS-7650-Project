# %%
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('%s-%s.pair' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
#     pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    pairs = []
    for l in lines:
        pairs.append([normalizeString(s) for s in l.split('\t')[:2]])
#     print(pairs)
    random.shuffle(pairs)

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)
    
    # # split test/training
    # pairs_test = pairs[int(0.8*len(pairs)):]
    # pairs = pairs[:int(0.8*len(pairs))]
    # return input_lang, output_lang, pairs, pairs_test
    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 100

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):
    # input_lang, output_lang, pairs, pairs_test = readLangs(lang1, lang2, reverse)
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)

    pairs_test = pairs[int(0.8*len(pairs)):]
    pairs = pairs[:int(0.8*len(pairs))]    
    return input_lang, output_lang, pairs, pairs_test


input_lang, output_lang, pairs, pairs_test = prepareData('bias', 'unbias', reverse=False)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 5128 sentence pairs
# Trimmed to 5128 sentence pairs
# Counting words...
# Counted words:
# bias 3790
# unbias 3313
# ['identifies how', 'argues that']

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            evaluateRandomly(encoder, decoder, n=5)
#             print('eval: ',evaluateRandomlyStats(encoder, decoder, n=1000))

# %%
def evaluateRandomlyStats(encoder, decoder, n=10):
    n_correct = 0
    for i in range(n):    
        # pair = random.choice(pairs_test)
        pair = pairs_test[i]
        # pair = random.choice(pairs)
        # print('>', pair[0])
        # print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        # print('<', output_sentence)
        if pair[1] in output_sentence:
          n_correct+=1
          # print('correct')
        # print('')
    return 1.*n_correct/n

# %%
# # prepare glove 1
# import numpy as np
# words = []
# word2idx = {}
# vectors = []

# glove_size = 100
# with open(f'./glove.6B.{glove_size}d.txt', 'rb') as f:
#     for idx,l in enumerate(f):
#         line = l.decode().split()
#         word = line[0]
#         words.append(word)
#         word2idx[word] = idx
#         vectors.append(np.array(line[1:]).astype(np.float))
# glove = {w: vectors[word2idx[w]] for w in words}

# %%
# # prepare glove embedding 2

# vocab_size = input_lang.n_words
# weight_matrix = np.zeros((vocab_size, glove_size))

# words_found = 0
# for i, word in enumerate(input_lang.word2count.keys()):
  
#   try:
#     weight_matrix[i] = glove[word]
#     words_found += 1
#   except KeyError as e:
#     # print('Key Error', e)
#     weight_matrix[i] = np.random.normal(scale=0.6, size=(glove_size, ))

# print("vocab_size", vocab_size)
# print("words found",words_found)
# weights = torch.from_numpy(weight_matrix)
# print('weight_matrix size',weights.size())

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class EncoderRNN_Glove(nn.Module):
    def __init__(self, input_size, hidden_size, weights):
        super(EncoderRNN_Glove, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        # self.embedding.load_state_dict({'weight':weight_matrix})
        self.embedding.weights = nn.Parameter(weights,requires_grad=False)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs_test)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
# hidden_size = glove_size
# encoder1 = EncoderRNN_Glove(input_lang.n_words, hidden_size, weights).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 100000, print_every=1000,learning_rate=0.03)
# Out:
# 0m 45s (- 75m 31s) (1000 1%) 4.4731
# > greater belief
# = more general advocacy
# < an <EOS>
#
# > accused of
# = described as
# < the to <EOS>
#
# > you are
# = one is
# < the to <EOS>
#
# > linux distribution
# = operating system
# < the to <EOS>
#
# > attempting to block
# = voting against
# < the not <EOS>
#
# 0m 54s (- 44m 11s) (2000 2%) 4.1723
# > excellent for
# = also capable of
# < an <EOS>
#
# > in fact
# = perceived as
# < the to <EOS>
#
# > could be
# = detractors have
# < is the <EOS>
#
# > dark age
# = middle ages
# < a in <EOS>
#
# >  minutes
# =  km
# < a <EOS>
#
# 1m 2s (- 33m 46s) (3000 3%) 4.0296
# > an english
# = a british
# < a a <EOS>
#
# > requires some explanation
# = is unusual
# < an unknown <EOS>
#
# > near cardiff
# = in south wales
# < a known <EOS>
#
# > guitar style
# = electric string
# < the the <EOS>
#
# > reality star
# = television personality
# < was  <EOS>
#
# 1m 11s (- 28m 33s) (4000 4%) 3.8666
# > leading scientific
# = conventional authoritative
# <   <EOS>
#
# > came to
# = arrived in
# < in by <EOS>
#
# > very tasty
# = are eaten
# < may in <EOS>
#
# > his spectacular performance
# = to perform well
# < has s <EOS>
#
# > were mostly stolen
# = borrowed heavily
# < the to <EOS>
#
# 1m 20s (- 25m 22s) (5000 5%) 3.4919
# > inspired by
# = based on
# < a of <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > linux distribution
# = operating system
# < operating system <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > attacked for
# = accused of
# < accused of <EOS>
#
# 1m 28s (- 23m 12s) (6000 6%) 3.3245
# > on remand
# = in prison
# < the of <EOS>
#
# > over two thirds
# = most also
# < political of <EOS>
#
# > and most importantly
# = as well as
# < best known <EOS>
#
# > old testament
# = hebrew bible
# < hebrew bible <EOS>
#
# > moral panic about
# = widespread disapproval of
# < that that <EOS>
#
# 1m 37s (- 21m 39s) (7000 7%) 3.0784
# > christmas eve
# =  december
# < is that <EOS>
#
# > a main
# = an important
# < an extensive <EOS>
#
# > a normal european
# = the standard latin
# < an extensive <EOS>
#
# > financial scheme promoters
# = political activists
# <   <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 1m 46s (- 20m 27s) (8000 8%) 2.8114
# > was wiped out
# = were all killed
# < the the <EOS>
#
# > appeared to be
# = said he was
# < says is is is is is <EOS>
#
# > at least partially
# = to an extent
# < one in <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > attack on
# = claim of
# < opposition out <EOS>
#
# 1m 55s (- 19m 32s) (9000 9%) 2.6223
# > economic stability
# = paper money
# < at of <EOS>
#
# > persist in basing
# = continue to base
# < the to <EOS>
#
# > singing sensation
# = popular singer
# < has widely <EOS>
#
# > terrorist cell
# = armed forces
# < militant of <EOS>
#
# > unpaid workers
# = other contributors
# < invites for <EOS>
#
# 2m 4s (- 18m 44s) (10000 10%) 2.5328
# > a radical
# = an outspoken
# < an high <EOS>
#
# > a war crime
# = an attack
# <  on <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > holistic health
# = alternative medicine
# < also s <EOS>
#
# > is stable
# = does exist
# < can be <EOS>
#
# 2m 14s (- 18m 4s) (11000 11%) 2.2396
# > an influential
# = a spanish
# < a major <EOS>
#
# > an interesting
# = a novel
# < a a a a  <EOS>
#
# > major step
# = significant move
# <  to <EOS>
#
# > searing set
# = european show
# < unix users <EOS>
#
# > intellectual elite
# = scientific mainstream
# < a in of <EOS>
#
# 2m 23s (- 17m 29s) (12000 12%) 2.1587
# > murder conviction
# = death sentence
# < independence positive <EOS>
#
# > protecting the unborn
# = restricting abortion
# < in claim <EOS>
#
# > an impressive
# = a substantial
# < a large <EOS>
#
# > an excessive
# = a significant
# < a new <EOS>
#
# > committed suicide
# = killed herself
# < killed himself <EOS>
#
# 2m 32s (- 16m 57s) (13000 13%) 1.9093
# > freedom fighter
# = social activist
# < indian indian activist <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > guitar style
# = electric string
# < citation styles <EOS>
#
# > judea and samaria
# = occupied palestinian territories
# < west bank <EOS>
#
# > outright reject
# = have rejected
# < traditionally rejects <EOS>
#
# 2m 41s (- 16m 29s) (14000 14%) 1.7905
# > passion play
# = independent film
# < constructing points <EOS>
#
# > microsoft windows computers
# = operating systems
# < other s <EOS>
#
# > best ever
# = most celebrated
# < most time <EOS>
#
# > wasa desecrated
# = was vandalised
# < taken for <EOS>
#
# > is known
# = promotes itself
# < was itself <EOS>
#
# 2m 50s (- 16m 4s) (15000 15%) 1.6660
# > pro life
# = against human abortion
# < anti abortion <EOS>
#
# > excellent examples
# = an example
# < has known <EOS>
#
# > minority access
# = affirmative action
# < is american <EOS>
#
# > bike tube
# = bicycle tubing
# < and of <EOS>
#
# > his or her
# = one s
# < the use <EOS>
#
# 2m 59s (- 15m 40s) (16000 16%) 1.5496
# > bloodthirsty sociopath
# = violent fighter
# < they to <EOS>
#
# > apartheid regime
# = south african government
# < south government government <EOS>
#
# > famous as
# = known for being
# < was being <EOS>
#
# > is widely
# = has been
# < has been <EOS>
#
# > at maximum
# = as posible
# < was disputed <EOS>
#
# 3m 8s (- 15m 18s) (17000 17%) 1.4293
# > distortions are
# = inequality is
# < influence be <EOS>
#
# > lived inside
# = were kept in
# <  that <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > cardassia n neutral
# = cardassian demilitarised
# < less strict <EOS>
#
# > in p p
# = on file sharing
# < are of <EOS>
#
# 3m 17s (- 14m 58s) (18000 18%) 1.3296
# > previously by
# = widely known as
# < became from <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > favorite ingredient in
# = part of
# < period of of <EOS>
#
# > is now
# = later became
# < became more <EOS>
#
# > has since clarified
# = later stated
# <  by <EOS>
#
# 3m 26s (- 14m 41s) (19000 19%) 1.2738
# > less leftist areas
# = more conservative communities
# < in acclaimed <EOS>
#
# > acclaim for
# = commentary on
# < accused of <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > a misguided
# = an apparent
# < an american <EOS>
#
# > he wishes
# = they wish
# < they wish <EOS>
#
# 3m 35s (- 14m 22s) (20000 20%) 1.2583
# > do not
# = neither discourage nor
# < doesn t <EOS>
#
# > an aparthied wall
# = a separation barrier
# < barrier barrier <EOS>
#
# > easily prevailed
# = also won
# < widespread widespread <EOS>
#
# > west philippine
# = south china
# < criticism to <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 3m 44s (- 14m 5s) (21000 21%) 1.0732
# > bare skin
# = the body
# < the s <EOS>
#
# > describes the
# = alleges a
# < move her <EOS>
#
# > some macedonians
# = macedonian slavs
# < widely number <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > pakistan supported terrorists
# = kashmiri militants
# < muslim shooters <EOS>
#
# 3m 53s (- 13m 48s) (22000 22%) 1.0566
# > her majesty
# = the queen
# < had an <EOS>
#
# > greater belief
# = more general advocacy
# < founding story <EOS>
#
# > a vulgar
# = an english
# < an his <EOS>
#
# > will definately
# = is predicted to
# < is syndicated <EOS>
#
# > the topmost
# = a well respected
# < a  <EOS>
#
# 4m 2s (- 13m 33s) (23000 23%) 0.9065
# > excellent prose
# = distinctive writing
# < also field <EOS>
#
# > that fulfills
# = intended to fulfill
# < in the <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > occupation of
# = policies in
# < forces in <EOS>
#
# > sexual predator
# = sex offender
# < the sex <EOS>
#
# 4m 11s (- 13m 17s) (24000 24%) 0.8430
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > is proficient
# = has dabbled
# < was a <EOS>
#
# > and special guests
# = as well as
# < other the <EOS>
#
# > a brutal
# = an ambitious
# < an american <EOS>
#
# > staging a rapid
# = the recent
# < an abduction <EOS>
#
# 4m 20s (- 13m 2s) (25000 25%) 0.8533
# > terrorist organizations
# = militant groups
# < militant militant <EOS>
#
# > public execution
# =  s killing
# < other film <EOS>
#
# > shunned a
# = left her initial
# < targetted in <EOS>
#
# > was well received
# = stopped en route
# < has been <EOS>
#
# > an awful
# = a poor
# < a complicated <EOS>
#
# 4m 29s (- 12m 48s) (26000 26%) 0.8536
# > american indians
# = native americans
# < the usa <EOS>
#
# > enjoy support
# = are supported
# < the of them <EOS>
#
# > ryan whiteis
# = adolf hitler
# < at movement <EOS>
#
# > communitarian tensions
# = communal relations
# < is limited <EOS>
#
# > is justified through
# = rests on
# < can be <EOS>
#
# 4m 38s (- 12m 34s) (27000 27%) 0.7119
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > leading scientific
# = conventional authoritative
# < science science <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > financial scheme promoters
# = political activists
# < the in <EOS>
# 4m 48s (- 12m 20s) (28000 28%) 0.6877
# > and most importantly
# = as well as
# < best known <EOS>
#
# > technical and powerful
# = technically complex
# < well known <EOS>
#
# > managed to
# = believed he
# < did of <EOS>
#
# > linux distribution
# = operating system
# < operating system <EOS>
#
# > an unprecedented
# = a controversial
# < a notable <EOS>
#
# 4m 56s (- 12m 7s) (29000 28%) 0.6477
# > is frequently
# = has been
# < has been <EOS>
#
# > korea n patriot
# = korean independence activist
# < political leader <EOS>
#
# > is a reminder
# = tries to show
# < was been some <EOS>
#
# > thracian tribe
# = people from thrace
# < has high <EOS>
#
# > will be
# = are usually
# < is promoted to <EOS>
#
# 5m 6s (- 11m 54s) (30000 30%) 0.6439
# > pre colonial
# = a historical
# < ethiopia n <EOS>
#
# > a british
# = an english
# < an english <EOS>
#
# > modern scientific
# = interpretations of
# < fringe science <EOS>
#
# > bedroom community
# = commuter town
# < has of <EOS>
#
# > the cruelty and
# = their perceived
# < countriesfor some a <EOS>
#
# 5m 15s (- 11m 41s) (31000 31%) 0.5788
# > self styled
# = also know
# < is world <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > occupied territories
# = west bank
# < west bank bank <EOS>
#
# > several instances
# = arguments in favor
# < indian believe of <EOS>
#
# > repression in
# = policies towards
# < with a <EOS>
#
# 5m 24s (- 11m 28s) (32000 32%) 0.5049
# > an infamous
# = a well known
# < a well known <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > to biblical times
# = thousands of years
# < middle kingdom <EOS>
#
# > he wishes
# = they wish
# < they wish <EOS>
#
# > infatuation with
# = feelings for
# < the for of <EOS>
#
# 5m 33s (- 11m 16s) (33000 33%) 0.5569
# > a chef doeuvre
# = an example
# < an advocacy <EOS>
#
# > was mostly negative
# = has been mixed
# < has been <EOS>
#
# > award winning
# = short film
# < was extreme <EOS>
#
# > secure base
# = new home
# < an experimental <EOS>
#
# > suicide attack s
# = terrorist attacks
# < democratic party <EOS>
#
# 5m 42s (- 11m 3s) (34000 34%) 0.5299
# > terrorist mastermind
# = muslim nationalist militant
# < militant movement <EOS>
#
# > is proficient
# = has dabbled
# < was used <EOS>
#
# > universal acclaim
# = positive reviews
# < mostly reviews reviews <EOS>
#
# > describes the
# = alleges a
# < presenting by <EOS>
#
# > without specifying
# =  alleging
# < have an <EOS>
#
# 5m 51s (- 10m 51s) (35000 35%) 0.4907
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > unpaid workers
# = other contributors
# < violent leader <EOS>
#
# > its progress
# = this change
# < change out <EOS>
#
# > ulterior motive
# = likely effect
# <  not <EOS>
#
# > the discovery of
# = europeans first encountered
# < a in <EOS>
#
# 6m 0s (- 10m 40s) (36000 36%) 0.4403
# > enjoyed in
# = tried using during
# < was on since <EOS>
#
# > each culture holds
# = many cultures hold
# < are hold <EOS>
#
# > this injustice
# = such discrimination
# < a british <EOS>
#
# > secure base
# = new home
# < an updated <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 6m 9s (- 10m 28s) (37000 37%) 0.4601
# > an egregious case
# = one example
# < a major <EOS>
#
# > sexual predator
# = sex offender
# < offender offender <EOS>
#
# > and ironically
# = as well as
# <   <EOS>
#
# > should be noted
# = is argued
# < continued that <EOS>
#
# > is much
# = may be
# < can believe benefits <EOS>
#
# 6m 18s (- 10m 16s) (38000 38%) 0.4517
# > revealed how these
# = stated that
# < is based <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > to biblical times
# = thousands of years
# < middle kingdom <EOS>
#
# > blessed with
# = has two
# < generally low <EOS>
#
# > a masked soldier
# = an unknown person
# < in in <EOS>
#
# 6m 27s (- 10m 5s) (39000 39%) 0.3586
# >  traditional
# = their ideals on
# <  ac <EOS>
#
# > human potential
# = large group awareness
# < with of <EOS>
#
# > zionist settlers
# = yishuv inhabitants
# < zionist of <EOS>
#
# > british isles
# = britain and ireland
# < ireland  <EOS>
#
# > carried out in
# = popularly associated with
# < was that <EOS>
#
# 6m 36s (- 9m 54s) (40000 40%) 0.3069
# > literary genius
# = author and educationist
# < cricketer cricketer <EOS>
#
# > intimate and insightful
# = often personal
# <  the <EOS>
#
# > failing to win
# = not winning
# < finalist finalist for <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > freedom fighter
# = independence activist
# < independence activist <EOS>
#
# 6m 45s (- 9m 43s) (41000 41%) 0.3777
# > an ultra
# = a far
# < a controversial <EOS>
#
# > absolute ruler
# = political leader
# < head of state <EOS>
#
# > apartheid regime
# = south african government
# < south african government <EOS>
#
# >  away
# =  home
# < died of <EOS>
#
# > dwayne hill
# = jonathan wilson
# < right to <EOS>
#
# 6m 54s (- 9m 31s) (42000 42%) 0.3651
# > north america
# = the americas
# < outside of japan <EOS>
#
# > attack upon
# = invasion of
# < deprecated in <EOS>
#
# > most often
# = sometimes simply
# < for example example <EOS>
#
# > seeks to rebut
# = argues against
# < non not <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 7m 3s (- 9m 21s) (43000 43%) 0.3753
# > the idea
# = a false perception
# < a ireland <EOS>
#
# > his or her
# = one s
# < the s <EOS>
#
# > an english
# = a british
# < a british <EOS>
#
# > certainly lends
# = may lend
# < quite believe <EOS>
#
# > an insignificant
# = a minor
# < a large <EOS>
#
# 7m 12s (- 9m 10s) (44000 44%) 0.3494
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > more weighty resources
# = competing sources
# < is the <EOS>
#
# > latin american countries
# = developing nations
# < widely believed <EOS>
#
# > pre colonial
# = a historical
# < ethiopia n <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 7m 21s (- 8m 59s) (45000 45%) 0.2769
# > criticism for
# = accusations of
# < aimed of <EOS>
#
# > against their enemies
# = about other nations
# < new groups <EOS>
#
# > this infamous day
# = the event
# < so far <EOS>
#
# > and ruthless gunmen
# = resistance fighters
# < other which <EOS>
#
# > some macedonians
# = macedonian slavs
# < may not <EOS>
#
# 7m 30s (- 8m 48s) (46000 46%) 0.2934
# >  away
# =  home
# <  of <EOS>
#
# > fell in
# = was involved
# < was with by <EOS>
#
# > billed as the
# = said to be
# < argues that <EOS>
#
# > recently released
# = currently working on
# < left the <EOS>
#
# > final defeat
# = last stand
# < closer defeated <EOS>
#
# 7m 39s (- 8m 37s) (47000 47%) 0.2860
# > reality star
# = television personality
# < television film <EOS>
#
# > has probably
# = may have
# < some have been <EOS>
#
# > a noble
# = an aristocrat
# < an american <EOS>
#
# > man does
# = humans do
# < was be stated <EOS>
#
# > that professed
# = who declared
# < the disputed <EOS>
#
# 7m 48s (- 8m 27s) (48000 48%) 0.2600
# > intellectual elite
# = scientific mainstream
# < in number of <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > earned some notoriety
# = found an audience
# < first famous famous <EOS>
#
# > as many as
# = between and
# < who claim be <EOS>
#
# > earned some notoriety
# = found an audience
# < first famous famous <EOS>
#
# 7m 57s (- 8m 16s) (49000 49%) 0.2296
# > the best
# = among them
# < a possible <EOS>
#
# > the idea
# = a false perception
# < northern ireland <EOS>
#
# > microsoft windows computers
# = operating systems
# < adopted leader <EOS>
#
# > christian bible
# = abrahamic religions
# < new testament <EOS>
#
# > fought bravely and
# = defended their posts
# < countriesfor instance <EOS>
#
# 8m 6s (- 8m 6s) (50000 50%) 0.2848
# > particulary irratates
# = particularly irritates
# < an organization <EOS>
#
# > launched his
# = printed an
# < a s <EOS>
#
# > part of
# = controlled by
# < ruled by <EOS>
#
# > was mostly negative
# = has been mixed
# < had no <EOS>
#
# > occupation of
# = policies in
# < presence over <EOS>
#
# 8m 15s (- 7m 55s) (51000 51%) 0.3113
# > occupied by
# = a part
# < incorporated into <EOS>
#
# > honored with
# = invited on
# < interpreted for <EOS>
#
# > has probably
# = may have
# < is due to <EOS>
#
# >  ostensibly
# = in order
# < claimed and <EOS>
#
# > a tremendous
# = an ardent
# < an influential <EOS>
#
# 8m 24s (- 7m 45s) (52000 52%) 0.2199
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > shadow chancellor
# = economic spokesman
# < a figure <EOS>
#
# > only become
# = are most
# < eventually became <EOS>
#
# > co eds
# = college students
# < the s <EOS>
#
# > kick demon ass
# = beat the demons
# < an american <EOS>
#
# 8m 33s (- 7m 34s) (53000 53%) 0.3038
# > terrorist group
# = paramilitary organization
# < militant organisation organisation <EOS>
#
# > stricter forms of
# = more closely to
# < republican president <EOS>
#
# > are very similar
# = have similarities
# < some are be <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > in p p
# = on file sharing
# < paramilitary of <EOS>
# 8m 42s (- 7m 24s) (54000 54%) 0.2414
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > evidence indicates
# = it appears
# < are his <EOS>
#
# > took credit
# = claimed responsibility
# < claimed responsibility <EOS>
#
# > invaluable to
# = readily apparent in
# < influence for <EOS>
#
# > treasured stories
# = cataloged descriptions
# < events that <EOS>
#
# 8m 51s (- 7m 14s) (55000 55%) 0.2298
# > sexual predator
# = sex offender
# < sex offender <EOS>
#
# > a bastard
# = an illegitimate
# < an influential <EOS>
#
# > an excellent
# = a diverse
# < a championship <EOS>
#
# > inspired by
# = based on
# < the part <EOS>
#
# > literary genius
# = author and educationist
# < excelled in academics <EOS>
#
# 8m 59s (- 7m 4s) (56000 56%) 0.2657
# > hammering of
# = win over
# < influenced on <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > killed herself
# = ended her life
# < identifies known <EOS>
#
# > in judaism
# = among religious jews
# < an armed <EOS>
#
# > the great
# = triple world champion
# < a influential <EOS>
#
# 9m 8s (- 6m 54s) (57000 56%) 0.2658
# > raped her
# = forced sex
# < forced sex <EOS>
#
# > thracian tribe
# = people from thrace
# < prominent a <EOS>
#
# > slanders against
# = public disputes with
# < proposal to change <EOS>
#
# > more neutral
# = less acidic
# < less strict <EOS>
#
# > is proficient
# = has dabbled
# < has a <EOS>
#
# 9m 17s (- 6m 44s) (58000 57%) 0.2641
# > best ever
# = most celebrated
# < most deadly <EOS>
#
# > the mitteleuropa
# = central europe
# < a one <EOS>
#
# > terrorist attacks
# = suicide attack s
# < political violence <EOS>
#
# > still agree
# = people believe
# < historians of <EOS>
#
# > an insignificant
# = a minor
# < a major <EOS>
#
# 9m 26s (- 6m 33s) (59000 59%) 0.2671
# > a unique
# = an unconventional
# < an eclectic <EOS>
#
# > terrorist attacks
# = suicide attack s
# < political violence <EOS>
#
# > intimate and insightful
# = often personal
# < the regarding <EOS>
#
# > a famed
# = is an
# < an the <EOS>
#
# > was mostly negative
# = has been mixed
# < the received <EOS>
#
# 9m 35s (- 6m 23s) (60000 60%) 0.1980
# > a victim of
# = affected by the
# < subject by <EOS>
#
# > an important
# = a decisive
# < a critically acclaimed <EOS>
#
# > a dilettante
# = an amateur
# < an the <EOS>
#
# > latin american countries
# = developing nations
# <  usa <EOS>
#
# > conspiracy theorist
# = fringe researcher
# < political activist <EOS>
#
# 9m 44s (- 6m 13s) (61000 61%) 0.2279
# > is stable
# = does exist
# < can be <EOS>
#
# > and ironically
# = as well as
# <  that <EOS>
#
# > public execution
# =  s killing
# < the other <EOS>
#
# > this sadistic tyrant
# = the sultan
# < the insurrectional <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 9m 53s (- 6m 3s) (62000 62%) 0.2274
# > a basic
# = an acidic
# < an more <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > a british
# = an english
# < an english <EOS>
#
# > asian supermodel
# = malaysian model
# < former model <EOS>
#
# > and ruthless gunmen
# = resistance fighters
# < militant movement <EOS>
#
# 10m 2s (- 5m 53s) (63000 63%) 0.1987
# > is frequently
# = has been
# < has been <EOS>
#
# > certainly recalls
# = may recall
# < military regarding <EOS>
#
# > wish to maintain
# = claim this maintains
# <  by <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > enigmatic man
# = arms dealer
# < its religious <EOS>
#
# 10m 11s (- 5m 43s) (64000 64%) 0.2492
# > the capital
# = a prominent part
# < an members <EOS>
#
# > we have
# = there is
# < there is <EOS>
#
# > the soviet statesman
# = a bolshevik leader
# < an n politician <EOS>
#
# > financier of
# = contributor to
# < change in <EOS>
#
# > minimal fees
# = a fee
# < was notable <EOS>
#
# 10m 20s (- 5m 34s) (65000 65%) 0.2385
# > more neutral
# = less acidic
# < less strict <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > described in
# = according to
# < adopted by <EOS>
#
# > the british isles
# = britian and ireland
# < these islands <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 10m 29s (- 5m 24s) (66000 66%) 0.2170
# > a brilliant
# = in an acclaimed
# < an accomplished <EOS>
#
# > an outrageously
# = a greatly
# < a successful <EOS>
#
# > voted to merge
# = was merged
# < best by <EOS>
#
# > improved with
# = modified to incorporate
# < but in <EOS>
#
# > claimed to have
# = says was
# < said he had <EOS>
#
# 10m 35s (- 5m 13s) (67000 67%) 0.1819
# > if he ejects
# = by ejecting
# < they are <EOS>
#
# > another ridiculous
# = a similar
# < political themselves <EOS>
#
# > he wishes
# = they wish
# < they wish <EOS>
#
# > the six counties
# = northern ireland
# < northern ireland <EOS>
#
# >  given
# = were granted
# < generally s <EOS>
#
# 10m 41s (- 5m 1s) (68000 68%) 0.2218
# > human rights
# = pro palestinian
# < homosexual behavior <EOS>
#
# > occupied by poland
# = under polish control
# < claiming into <EOS>
#
# > suffers from autism
# = is autistic
# < is autistic <EOS>
#
# > traditional values
# = social conservative
# < socially conservative <EOS>
#
# > the long awaited
# = an upcoming
# < new of <EOS>
#
# 10m 47s (- 4m 50s) (69000 69%) 0.2257
# > terrorists associated with
# = associates of
# < interpreted she <EOS>
#
# >  away
# =  home
# < died <EOS>
#
# > the best
# = among them
# < a excellend <EOS>
#
# > the highest rated
# = was a
# < these popular <EOS>
#
# > achieved notoriety
# = made the spotlight
# < became famous <EOS>
#
# 10m 53s (- 4m 40s) (70000 70%) 0.1918
# > most best
# = more popular
# < best of <EOS>
#
# > most famously
# = such as
# < such as <EOS>
#
# > national hero
# = nationalist leader
# < viet cong bomber <EOS>
#
# > is tainted
# = was complicated
# < has be used <EOS>
#
# > stricter forms of
# = more closely to
# < republican president <EOS>
#
# 10m 59s (- 4m 29s) (71000 71%) 0.1787
# > american terrorist
# = oklahoma city bomber
# < political revolutionary <EOS>
#
# > the pilgrim trade
# = many pilgrims
# < a prominent of <EOS>
#
# > volunteer within
# = member of
# < second very <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 11m 5s (- 4m 18s) (72000 72%) 0.1911
# > remarkable fact in
# = feat of
# < claimed to <EOS>
#
# > on remand
# = in prison
# < the book <EOS>
#
# > the topmost
# = a well respected
# < a highly <EOS>
#
# > protecting the unborn
# = restricting abortion
# < the in <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 11m 12s (- 4m 8s) (73000 73%) 0.2117
# > neutrally selected gene
# = neutral mutation
# < a member <EOS>
#
# > could be
# = detractors have
# < have been <EOS>
#
# > fiat currency
# = legal tender
# < used in <EOS>
#
# > touched on
# = taken up
# < opposition regarding <EOS>
#
# > financier of
# = contributor to
# < historically in <EOS>
#
# 11m 18s (- 3m 58s) (74000 74%) 0.2281
# > operated black box
# = used electronic
# <  wealthy <EOS>
#
# > as dictated by
# = in accordance with
# < accepted into <EOS>
#
# > he basically quit
# = broken rib
# < has not <EOS>
#
# > supporting illegal
# = his position on
# < disputed disputed <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 11m 24s (- 3m 48s) (75000 75%) 0.2368
# > an antisemitic hoax
# = a book
# < a major <EOS>
#
# > excellent for
# = also capable of
# < aimed of of <EOS>
#
# > claimed to have
# = says was
# < wrote he he <EOS>
#
# > claimed was
# = regarded as
# < said were were <EOS>
#
# > a misinterpretation
# = an idiosyncratic interpretation
# < an based <EOS>
#
# 11m 30s (- 3m 38s) (76000 76%) 0.1620
# > universally wanted
# = some widely used
# < had the <EOS>
#
# > individual liberty
# = libertarian causes
# < a major <EOS>
#
# > a radical
# = an outspoken
# < an american <EOS>
#
# > linux distribution
# = operating system
# < operating system <EOS>
#
# > the highest rated
# = was a
# < several popular <EOS>
#
# 11m 37s (- 3m 28s) (77000 77%) 0.1761
# > a delicious
# = an example
# < an advocacy <EOS>
#
# > and needlessly phrased
# =  phrasing
# < the leader <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > infatuation with
# = feelings for
# < modified to <EOS>
#
# > their assailants
# = the officers
# < was criticism <EOS>
#
# 11m 42s (- 3m 18s) (78000 78%) 0.2132
# > of india
# = under indian administration
# < pakistan pakistan <EOS>
#
# > his reason
# = the motivation
# < a s <EOS>
#
# > losing streak to
# = rivalry with
# < inspired of <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > official teachings
# = conservative wing
# <  divisive <EOS>
#
# 11m 48s (- 3m 8s) (79000 79%) 0.1881
# > attack on
# = claim of
# < operation at <EOS>
#
# > a unique
# = an unconventional
# < an eclectic <EOS>
#
# > comical genius is
# = comedic methods are
# < they are <EOS>
#
# > take you
# = the user
# < allows travelers <EOS>
#
# > bike tube
# = bicycle tubing
# < islamic and <EOS>
# 11m 54s (- 2m 58s) (80000 80%) 0.2041
# > a linux distribution
# = an operating system
# < an operating system <EOS>
#
# > unceded territory
# = a reserve
# < disputed land <EOS>
#
# > the victory
# = fall of communism
# < a victorious <EOS>
#
# > plagued with
# = subject to
# < subject to <EOS>
#
# > an oasis
# = a place
# < a major <EOS>
#
# 12m 0s (- 2m 49s) (81000 81%) 0.2424
# > hostile to
# = at odds with
# < independent from <EOS>
#
# > essential in
# = part of
# < accused of <EOS>
#
# > middle east
# = southwest asia
# < north eurasian <EOS>
#
# > the devilish
# = dr .
# < to well <EOS>
#
# > started a relationship
# = cheated on her
# < an less <EOS>
#
# 12m 6s (- 2m 39s) (82000 82%) 0.2342
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > refuse to accept
# = do not believe
# < became not <EOS>
#
# > the most distinguished
# = a lighter weight
# < a integral <EOS>
#
# > the discovery of
# = europeans first encountered
# < a arrival <EOS>
#
# > spoilt brats
# = upper class teenagers
# < democratic on <EOS>
#
# 12m 12s (- 2m 30s) (83000 83%) 0.1886
# > an excellent
# = a widely used
# < a popular <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > seemingly violating
# = claiming to violate
# < the of <EOS>
#
# > has fled to
# = is now in
# < resettled in <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 12m 18s (- 2m 20s) (84000 84%) 0.1806
# > birth of christ
# = common era
# < common era <EOS>
#
# > udit kabra
# = a student
# < also rights <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > the great
# = triple world champion
# < a influential <EOS>
#
# > committed suicide
# = killed herself
# < killed herself <EOS>
#
# 12m 24s (- 2m 11s) (85000 85%) 0.2129
# > cling onto
# = remain in
# < the neutral <EOS>
#
# > handful of warriors
# = small force
# < its in <EOS>
#
# > socialist communist
# = opinion oriented
# < left system <EOS>
#
# > it should be
# = is generally
# < is typically <EOS>
#
# > the devilish
# = dr .
# < to well <EOS>
#
# 12m 30s (- 2m 2s) (86000 86%) 0.2117
# > are wealthy enough
# = can afford
# < actually turned <EOS>
#
# > universal acclaim
# = very positive reviews
# < mostly positive reviews <EOS>
#
# > is tainted
# = was complicated
# < has used <EOS>
#
# > then prophet
# = church president
# < islamic lawmaker <EOS>
#
# > best ever
# = most celebrated
# < most deadly <EOS>
#
# 12m 36s (- 1m 53s) (87000 87%) 0.2105
# > half breed
# = mixed race
# < united states <EOS>
#
# > advanced slowly
# = been controversial
# < most change <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > was there
# = remained operational
# < even been <EOS>
#
# > west philippine
# = south china
# < east in <EOS>
#
# 12m 42s (- 1m 44s) (88000 88%) 0.1665
# > a normal european
# = the standard latin
# < the movie <EOS>
#
# > kick demon ass
# = beat the demons
# < had american <EOS>
#
# > the democrats thought
# = abc news argued
# < a more <EOS>
#
# > recent upstart
# = modern esoteric
# < extremely widespread <EOS>
#
# > and edged out
# =  winning against
# < was argued <EOS>
#
# 12m 48s (- 1m 35s) (89000 89%) 0.2003
# > refused to
# = did not
# < did not <EOS>
#
# > the best
# = among them
# < a american <EOS>
#
# > must be
# = is very likely
# < was often <EOS>
#
# > one single altered
# = altering any
# < indian film <EOS>
#
# > pro family
# = socially conservative
# < and socially conservative <EOS>
#
# 12m 54s (- 1m 26s) (90000 90%) 0.1867
# > an amateur blogger
# = a citizen journalist
# < a law <EOS>
#
# > ryan whiteis
# = adolf hitler
# < at based <EOS>
#
# > judea and samaria
# = occupied palestinian territories
# < west west west <EOS>
#
# > pro
# = opposed to criminalizing
# < a  <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 13m 1s (- 1m 17s) (91000 91%) 0.2213
# > he is
# = they are
# < they re <EOS>
#
# > provides breathtaking
# = provide a scenic
# < often impressive <EOS>
#
# > black pope
# = superior general
# < fluffy about <EOS>
#
# > the rightful
# = its initial
# < a significant <EOS>
#
# > attacks on
# = resistance to
# < outcry over <EOS>
#
# 13m 7s (- 1m 8s) (92000 92%) 0.2105
# > the organization notes
# = they note
# < a large <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > returned to
# = incorporated with
# < was annexed by <EOS>
#
# > was well received
# = stopped en route
# < widely claimed <EOS>
#
# > a misguided
# = an apparent
# < an american <EOS>
#
# 13m 13s (- 0m 59s) (93000 93%) 0.2179
# > later excluded
# = not included
# < homosexual to <EOS>
#
# > american terrorist
# = oklahoma city bomber
# < political revolutionary <EOS>
#
# > caught blatantly
# = accused of
# <  although it <EOS>
#
# > people of color
# = non whites
# < who to <EOS>
#
# > against their enemies
# = about other nations
# < new organization <EOS>
#
# 13m 19s (- 0m 51s) (94000 94%) 0.1909
# > is frequently
# = has been
# < can been <EOS>
#
# > artificially altering
# = intentionally managing
# < gay and <EOS>
#
# > eco terrorism
# = animal rights
# < animal rights <EOS>
#
# > overly elaborate
# = comparatively expansive
# < one their <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 13m 26s (- 0m 42s) (95000 95%) 0.2380
# > certainly recalls
# = may recall
# < military regarding <EOS>
#
# > it is believed
# = he believes
# < some believe <EOS>
#
# > still agree
# = people believe
# < historians of <EOS>
#
# > terrorist cell
# = armed forces
# < militant and <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# 13m 32s (- 0m 33s) (96000 96%) 0.1922
# > holy koran
# = qur an
# < qur an <EOS>
#
# > a positive
# = the subsequent
# < an armed <EOS>
#
# > a politicised controversy
# = politically controversial
# < the disagreement <EOS>
#
# > public opinion
# = mainstream mass media
# < scientific consensus <EOS>
#
# > struggling against
# = faced with
# < home service <EOS>
#
# 13m 38s (- 0m 25s) (97000 97%) 0.1870
# > an influential
# = a spanish
# < a major <EOS>
#
# > a famed
# = is an
# < an less <EOS>
#
# > a candidate
# = an option
# < an english <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > zionist occupation
# = israeli army
# < longtime of <EOS>
#
# 13m 44s (- 0m 16s) (98000 98%) 0.1874
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > criticism for
# = accusations of
# < accused of <EOS>
#
# > half breed
# = mixed race
# < united states <EOS>
#
# > practically nullified
# = sharply conflicted with
# < which and <EOS>
#
# > requires some explanation
# = is unusual
# < may idea <EOS>
#
# 13m 50s (- 0m 8s) (99000 99%) 0.1989
# > as many as
# = between and
# < who of being <EOS>
#
# > regular party animal
# = regularly attending parties
# < expressed s <EOS>
#
# > adherence to
# = interpretation of
# < left of <EOS>
#
# > of why
# = arguing that
# < argues that <EOS>
#
# > a misinterpretation
# = an idiosyncratic interpretation
# < an based <EOS>
#
# 13m 56s (- 0m 0s) (100000 100%) 0.1823
# > infested with
# = occupied by
# < inhabited by <EOS>
#
# > liberation movement
# = militant group
# < militant organization <EOS>
#
# > the bible
# = witness doctrines
# < new testament <EOS>
#
# > a main
# = an important
# < an key <EOS>
#
# > caught blatantly
# = accused of
# <  although <EOS>

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > a traditional powerhouse
# = traditionally strong
# < the notable <EOS>
#
# > only become
# = are most
# < even becoming <EOS>
#
# > excelled at
# = played competitive
# < played competitive <EOS>
#
# > committed suicide
# = killed herself
# < killed himself <EOS>
#
# > most famous
# = best known
# < best known <EOS>
#
# > an obscure legislative
# = a constitutional
# < a united <EOS>
#
# > great patriotic
# = second world
# < second world <EOS>
#
# > enigmatic man
# = arms dealer
# < its nasal <EOS>
#
# > in an idyllic
# = by a
# < a pastoral <EOS>
#
# > you are
# = one is
# < the player is <EOS>

# %%
def evaluateRandomlyStats(encoder, decoder, n=10):
    n_correct = 0
    for i in range(n):    
        # pair = random.choice(pairs_test)
        pair = pairs_test[i]
        # pair = random.choice(pairs)
        # print('>', pair[0])
        # print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        # print('<', output_sentence)
        if pair[1] in output_sentence:
          n_correct+=1
          # print('correct')
        # print('')
    return 1.*n_correct/n

# %%
evaluateRandomlyStats(encoder1, attn_decoder1, n=1000)
# Out:
# 0.178
